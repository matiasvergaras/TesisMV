# %%
import os
import pickle
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

from PIL import Image
import math
from sklearn.metrics import accuracy_score,hamming_loss, accuracy_score, f1_score, precision_score, recall_score

# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.metrics import multilabel_confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report

from textwrap import wrap


from utils import KunischMetrics
from utils import KunischPruner
from utils import DataExplorer
from utils import KunischPlotter

# %%
output_dir = os.path.join('..', 'outputs', 'alexnet26l')
target = 'mr4'
target_name = '4-Match Ratio'

scores_no_pw = []
scores_pw = []

experimentos = os.listdir(output_dir)
apellidos = ['', '_weighted_1']


# Iterar sobre archivos de resultados sacando el target buscado
for exp in experimentos:
    for apellido in apellidos:
        path_predicciones = os.path.join(output_dir, exp, f'{26}L{apellido}', 'metadata.csv')
        predicciones = pd.read_csv(path_predicciones, index_col = 0)
        score = float(predicciones.loc[[target]].values[0][0])
        #print(path_predicciones, score[0][0])
        if apellido == '':
            scores_no_pw.append(score)
        else:
            scores_pw.append(score)
        print(exp, apellido, score)
# Out:
# base  0.0412
# base _weighted_1 0.25
# blur  0.0503
# blur _weighted_1 0.2448
# blur_rain_ref_rot_crop1_elastic1  0.058
# blur_rain_ref_rot_crop1_elastic1 _weighted_1 0.259
# blur_rain_ref_rot_crop1_randaug1_elastic1  0.0348
# blur_rain_ref_rot_crop1_randaug1_elastic1 _weighted_1 0.259
# blur_rain_ref_rot_elastic1  0.0515
# blur_rain_ref_rot_elastic1 _weighted_1 0.2616
# crop1  0.0206
# crop1 _weighted_1 0.2732
# elastic1  0.0503
# elastic1 _weighted_1 0.2423
# gausblur1  0.0567
# gausblur1 _weighted_1 0.2255
# mtnblur  0.0052
# mtnblur _weighted_1 0.2694
# rain  0.0567
# rain _weighted_1 0.2204
# rain_ref_rot  0.0541
# rain_ref_rot _weighted_1 0.2745
# rain_ref_rot_elastic1  0.0515
# rain_ref_rot_elastic1 _weighted_1 0.2693
# randaug1  0.0631
# randaug1 _weighted_1 0.259
# ref  0.0619
# ref _weighted_1 0.2539
# ref_rot  0.0618
# ref_rot _weighted_1 0.2732
# rot  0.0863
# rot _weighted_1 0.2564

# %%
techniques = []
for exp in experimentos:
    if 'weighted' not in exp:
        label = exp.replace('_', ' ')
        label = label.replace('1', '')
        techniques.append(label)
techniques
# Out:
# ['base',
#  'blur',
#  'blur rain ref rot crop elastic',
#  'blur rain ref rot crop randaug elastic',
#  'blur rain ref rot elastic',
#  'crop',
#  'elastic',
#  'gausblur',
#  'mtnblur',
#  'rain',
#  'rain ref rot',
#  'rain ref rot elastic',
#  'randaug',
#  'ref',
#  'ref rot',
#  'rot']

# %%
plt.rcParams.update({'font.size': 11})
plt.rcParams['figure.dpi'] = 1000

# %%
# ordenar 
s_pw, s_no_pw, techsorted = zip(*sorted(zip(scores_pw, scores_no_pw, techniques)))

for i in range(0, len(techniques)):
    print(techsorted[i], s_pw[i], s_no_pw[i])
    
# wrap de las etiquetas cuando exceden cierto largo
techsorted = ['\n'.join(wrap(l, 22)) for l in techsorted]

fig, ax = plt.subplots()
width = 0.7

if s_pw[0]>s_no_pw[0]:
    b1 = ax.barh(techsorted, s_pw, width, label = 'Con P.W., K = 1', color='tab:blue', alpha=1)
    b2 = ax.barh(techsorted, s_no_pw, width, label = 'Sin P.W.', color='tab:orange', alpha=1)
    order = [3, 2, 0, 1]

else:
    b2 = ax.barh(techsorted, s_no_pw, width, label = 'Sin P.W.', color='tab:orange', alpha=1)
    b1 = ax.barh(techsorted, s_pw, width, label = 'Con P.W., K = 1', color='tab:blue', alpha=1)
    order = [2, 3, 0, 1]


ax.set_xlabel(target_name)
ax.set_ylabel('Técnicas de Data Augmentation')

ax.set_title(target_name + ' al variar P.W.  \nAlexNet base, 26 etiquetas más frecuentes')

# linea horizontal marcando el resultado base no pw
index_base = techsorted.index('base')
plt.vlines(x=s_no_pw[index_base], color='red', linewidth=2, 
           ymin=-0.5, ymax=15.5, label = 'Base, sin P.W.',
           alpha=0.8)
plt.vlines(x=s_pw[index_base], color='black', linewidth=2,
           ymin=-0.5, ymax=15.5, label = 'Base, con P.W. K=1',
           alpha=0.8)

# rotar labels del eje x
#plt.xticks(rotation=90)
fig.set_size_inches(8, 11)
fig.set_dpi(200)

ax.grid(which='both')
ax.minorticks_on()
# Customize the major grid
ax.grid(which='major', linestyle='-', linewidth='1', alpha=0.5)
# Customize the minor grid
ax.grid(which='minor', linestyle=':', linewidth='1', alpha=0.5)

            
# legends en orden deseado
handles, ls = plt.gca().get_legend_handles_labels()
ax.legend([handles[idx] for idx in order],[ls[idx] for idx in order], loc="upper left")
ax.bar_label(b1, fmt= '%.4f', padding=-60)
ax.bar_label(b2, fmt= '%.4f', padding=-60)
    
ax.set_xlim(0, 1)
plt.show()
# Out:
# rain 0.2204 0.0567
# gausblur 0.2255 0.0567
# elastic 0.2423 0.0503
# blur 0.2448 0.0503
# base 0.25 0.0412
# ref 0.2539 0.0619
# rot 0.2564 0.0863
# blur rain ref rot crop randaug elastic 0.259 0.0348
# blur rain ref rot crop elastic 0.259 0.058
# randaug 0.259 0.0631
# blur rain ref rot elastic 0.2616 0.0515
# rain ref rot elastic 0.2693 0.0515
# mtnblur 0.2694 0.0052
# crop 0.2732 0.0206
# ref rot 0.2732 0.0618
# rain ref rot 0.2745 0.0541
